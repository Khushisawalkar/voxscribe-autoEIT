# %% [markdown]
# # AutoEIT Speech Transcription Pipeline
# HumanAI GSoC 2026 Evaluation Test

# %% [markdown]
# ## Introduction
#
# The Elicited Imitation Task (EIT) is used in linguistic research to evaluate language proficiency.
#
# This project develops a transcription pipeline that converts Spanish learner speech recordings into text while preserving disfluencies and grammatical errors.

# %%
print("VoxScribe transcription environment ready")
# Out:
# VoxScribe transcription environment ready

# %%
# !pip install openai-whisper librosa pandas numpy jiwer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/803.2 kB ? eta -:--:--
#      ---------------------------------------- 803.2/803.2 kB 6.4 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.8 MB 6.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 6.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
# ...

# %% [markdown]
# ## Dataset
#
# The dataset contains Spanish EIT recordings where participants repeat target sentences.
#
# Each recording represents learner speech that may include hesitations, pronunciation variation, and grammatical errors.

# %%
import os
import whisper
import pandas as pd

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\khush\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import sys!{sys.executable} -m pip install openai-whisper

# %%
import sys
# !{sys.executable} -m pip install openai-whisper

# %%
import sys
print("Python path:", sys.executable)
# Out:
# Python path: C:\Users\khush\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import whisper
model = whisper.load_model("base")
print("Whisper loaded successfully")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:07<00:00, 19.3MiB/s]
# Whisper loaded successfully

# %% [markdown]
# ## Transcription Pipeline
#
# The following code processes audio files and generates transcripts using the Whisper ASR model.

# %%
import whisper

model = whisper.load_model("base")

print("Whisper model loaded")
# Out:
# Whisper model loaded

# %%
# !pip install imageio-ffmpeg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\khush\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install imageio-ffmpeg
# Out:
# ...
#    ---------------------------------------- 0.0/31.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/31.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/31.2 MB 1.9 MB/s eta 0:00:17
#    - -------------------------------------- 1.3/31.2 MB 2.2 MB/s eta 0:00:14
#    -- ------------------------------------- 1.6/31.2 MB 2.2 MB/s eta 0:00:14
#    -- ------------------------------------- 1.8/31.2 MB 1.8 MB/s eta 0:00:17
#    -- ------------------------------------- 1.8/31.2 MB 1.8 MB/s eta 0:00:17
#    -- ------------------------------------- 2.1/31.2 MB 1.5 MB/s eta 0:00:20
#    -- ------------------------------------- 2.1/31.2 MB 1.5 MB/s eta 0:00:20
#    -- ------------------------------------- 2.1/31.2 MB 1.5 MB/s eta 0:00:20
#    --- ------------------------------------ 2.4/31.2 MB 1.1 MB/s eta 0:00:26
#    ---- ----------------------------------- 3.1/31.2 MB 1.3 MB/s eta 0:00:21
# ...

# %%
import imageio_ffmpeg
print(imageio_ffmpeg.get_ffmpeg_exe())
# Out:
# C:\Users\khush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe

# %%
import os
import imageio_ffmpeg

ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()
os.environ["PATH"] += os.pathsep + os.path.dirname(ffmpeg_path)

print("FFmpeg ready:", ffmpeg_path)
# Out:
# FFmpeg ready: C:\Users\khush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe

# %%
import whisper
model = whisper.load_model("base")

# %%
import whisper
import os

model = whisper.load_model("base")

audio_file = "../data/038010_EIT-2A.mp3"

result = model.transcribe(audio_file, language="es")

print(result["text"])
# Out:
# C:\Users\khush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In[13], line 8
#       4 model = whisper.load_model("base")
#       6 audio_file = "../data/038010_EIT-2A.mp3"
# ----> 8 result = model.transcribe(audio_file, language="es")
#      10 print(result["text"])
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\whisper\transcribe.py:139, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, carry_initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, clip_timestamps, hallucination_silence_threshold, **decode_options)
# ...

# %%
import sys
# !{sys.executable} -m pip install imageio-ffmpeg

# %%
import imageio_ffmpeg

ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()
print(ffmpeg_path)
# Out:
# C:\Users\khush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe

# %%
import os
import imageio_ffmpeg

ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()

os.environ["PATH"] += os.pathsep + os.path.dirname(ffmpeg_path)

print("FFmpeg ready")
# Out:
# FFmpeg ready

# %%
import whisper

model = whisper.load_model("base")

# %%
import os
import imageio_ffmpeg

ffmpeg_exe = imageio_ffmpeg.get_ffmpeg_exe()

os.environ["FFMPEG_BINARY"] = ffmpeg_exe

print("FFmpeg set to:", ffmpeg_exe)
# Out:
# FFmpeg set to: C:\Users\khush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win-x86_64-v7.1.exe

# %%
import whisper

model = whisper.load_model("base")

# %%
audio_file = "../data/038010_EIT-2A.mp3"

result = model.transcribe(audio_file, language="es")

print(result["text"])
# Out:
# ---------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In[22], line 3
#       1 audio_file = "../data/038010_EIT-2A.mp3"
# ----> 3 result = model.transcribe(audio_file, language="es")
#       5 print(result["text"])
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\whisper\transcribe.py:139, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, carry_initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, clip_timestamps, hallucination_silence_threshold, **decode_options)
#     136     decode_options["fp16"] = False
#     138 # Pad 30-seconds of silence to the input audio, for slicing
# --> 139 mel = log_mel_spectrogram(audio, model.dims.n_mels, padding=N_SAMPLES)
#     140 content_frames = mel.shape[-1] - N_FRAMES
# ...
